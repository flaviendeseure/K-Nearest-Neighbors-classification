# %%
# !pip install pyforest
import pyforest
from sklearn import metrics
# Out:
# Collecting pyforest
#   Downloading pyforest-1.0.3.tar.gz (14 kB)
# Building wheels for collected packages: pyforest
#   Building wheel for pyforest (setup.py): started
#   Building wheel for pyforest (setup.py): finished with status 'done'
#   Created wheel for pyforest: filename=pyforest-1.0.3-py2.py3-none-any.whl size=13720 sha256=e350ab193a463987852914ffc052db71cc8bab5807abaad0a25827e0230f54c0
#   Stored in directory: c:\users\flavi\appdata\local\pip\cache\wheels\0e\b5\b2\e35eb1ece8ddf1cd70c19aeb7927121f6ddf329e27cdd3f99b
# Successfully built pyforest
# Installing collected packages: pyforest
# Successfully installed pyforest-1.0.3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import load_iris

from sklearn.preprocessing import RobustScaler, MinMaxScaler, StandardScaler

from sklearn.model_selection import train_test_split

from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV

from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-9dad26432fb3> in <module>
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import matplotlib.pyplot as plt
#       4
#       5 from sklearn.datasets import load_iris
#
# C:\Users\flavi\anaconda3\envs\inmoov\lib\site-packages\matplotlib\pyplot.py in <module>
#      34 from cycler import cycler
#      35 import matplotlib
# ---> 36 import matplotlib.colorbar
#      37 import matplotlib.image
#      38 from matplotlib import rcsetup, style
#
# C:\Users\flavi\anaconda3\envs\inmoov\lib\site-packages\matplotlib\colorbar.py in <module>
#      42 import matplotlib.collections as collections
#      43 import matplotlib.colors as colors
# ---> 44 import matplotlib.contour as contour
#      45 import matplotlib.cm as cm
#      46 import matplotlib.gridspec as gridspec
#
# C:\Users\flavi\anaconda3\envs\inmoov\lib\site-packages\matplotlib\contour.py in <module>
#      23
#      24 # Import needed for adding manual selection capability to clabel
# ---> 25 from matplotlib.blocking_input import BlockingContourLabeler
#      26
#      27 # We can't use a single line collection for contour because a line
#
# C:\Users\flavi\anaconda3\envs\inmoov\lib\site-packages\matplotlib\blocking_input.py in <module>
#      24
#      25 from matplotlib import cbook
# ---> 26 from matplotlib.backend_bases import MouseButton
#      27 import matplotlib.lines as mlines
#      28
#
# C:\Users\flavi\anaconda3\envs\inmoov\lib\site-packages\matplotlib\backend_bases.py in <module>
#      43
#      44 import matplotlib as mpl
# ---> 45 from matplotlib import (
#      46     backend_tools as tools, cbook, colors, textpath, tight_bbox,
#      47     transforms, widgets, get_backend, is_interactive, rcParams)
#
# C:\Users\flavi\anaconda3\envs\inmoov\lib\site-packages\matplotlib\widgets.py in <module>
#       1 import numpy as np
# ----> 2 import matplotlib.pyplot as plt
#       3 from matplotlib.widgets import Slider, Button, RadioButtons
#       4
#       5 # The parametrized function to be plotted
#
# AttributeError: module 'matplotlib' has no attribute 'pyplot'

# %%
colnames = [f"Var{i}" for i in range(1,7)]
colnames.append("Class")
df = pd.read_csv("data.csv",names=colnames)
df.head()
# Out:
#        Var1     Var2      Var3      Var4      Var5     Var6   Class
# 0  5.316975  1.18127 -0.040245  1.566224  0.804565  0.01365  classB
# 1  5.242525  1.12047 -0.030245  1.514974  0.814565  0.00365  classB
# 2  4.580975  0.88392  0.009755  1.287924  0.814565 -0.05635  classD
# 3  3.731775  0.93762 -0.140245  1.136574  0.814565  0.09365  classC
# 4  4.500925  1.04847 -0.140245  1.271224  0.794565  0.08365  classA

# %%
print(df.describe())
# Out:
#              Var1        Var2        Var3        Var4        Var5        Var6
# count  803.000000  803.000000  803.000000  803.000000  803.000000  803.000000
# mean     4.840189    1.084546   -0.071129    1.408835    0.810642    0.030574
# std      1.015314    0.240708    0.053829    0.292606    0.005966    0.047720
# min      3.398525    0.772920   -0.300245    1.027724    0.774565   -0.086350
# 25%      4.072750    0.928695   -0.110245    1.209674    0.804565   -0.006350
# 50%      4.720875    0.992570   -0.070245    1.342824    0.814565    0.033650
# 75%      5.265075    1.180220   -0.030245    1.519574    0.814565    0.063650
# max      9.476125    2.132970    0.039755    2.771174    0.814565    0.163650

# %%
X=df[colnames[:-1]] 
X=X.drop(["Var5","Var3"],axis=1)
y=df[colnames[-1]].apply(lambda x: x[-1])

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
import lazypredict
from lazypredict.Supervised import LazyClassifier

# %%
clf = LazyClassifier()
models, predictions = clf.fit(X_train, X_test, y_train, y_test)
models
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 29/29 [00:01<00:00, 14.81it/s]
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# QuadraticDiscriminantAnalysis      0.93               0.94    None      0.93
# LinearDiscriminantAnalysis         0.93               0.93    None      0.92
# CalibratedClassifierCV             0.92               0.93    None      0.92
# LinearSVC                          0.92               0.92    None      0.91
# LogisticRegression                 0.91               0.91    None      0.90
# PassiveAggressiveClassifier        0.90               0.91    None      0.90
# SVC                                0.91               0.91    None      0.90
# LabelSpreading                     0.90               0.90    None      0.90
# LabelPropagation                   0.90               0.90    None      0.90
# XGBClassifier                      0.90               0.90    None      0.89
# KNeighborsClassifier               0.90               0.90    None      0.89
# LGBMClassifier                     0.89               0.89    None      0.88
# ExtraTreesClassifier               0.88               0.89    None      0.88
# BaggingClassifier                  0.88               0.88    None      0.87
# GaussianNB                         0.88               0.88    None      0.87
# RandomForestClassifier             0.87               0.88    None      0.87
# SGDClassifier                      0.85               0.87    None      0.85
# NearestCentroid                    0.86               0.87    None      0.86
# DecisionTreeClassifier             0.85               0.86    None      0.85
# Perceptron                         0.83               0.85    None      0.83
# ExtraTreeClassifier                0.82               0.84    None      0.82
# AdaBoostClassifier                 0.78               0.80    None      0.78
# RidgeClassifier                    0.74               0.76    None      0.70
# RidgeClassifierCV                  0.74               0.73    None      0.71
# BernoulliNB                        0.74               0.64    None      0.71
# DummyClassifier                    0.19               0.16    None      0.18
#
#                                Time Taken
# Model
# QuadraticDiscriminantAnalysis        0.02
# LinearDiscriminantAnalysis           0.02
# CalibratedClassifierCV               0.18
# LinearSVC                            0.06
# LogisticRegression                   0.04
# PassiveAggressiveClassifier          0.02
# SVC                                  0.04
# LabelSpreading                       0.03
# LabelPropagation                     0.02
# XGBClassifier                        0.19
# KNeighborsClassifier                 0.02
# LGBMClassifier                       0.38
# ExtraTreesClassifier                 0.13
# BaggingClassifier                    0.04
# GaussianNB                           0.02
# RandomForestClassifier               0.37
# SGDClassifier                        0.03
# NearestCentroid                      0.01
# DecisionTreeClassifier               0.02
# Perceptron                           0.02
# ExtraTreeClassifier                  0.01
# AdaBoostClassifier                   0.13
# RidgeClassifier                      0.04
# RidgeClassifierCV                    0.04
# BernoulliNB                          0.01
# DummyClassifier                      0.02
